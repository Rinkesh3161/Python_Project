# %%
# in this project we use both libraries such as SELENIUM and BS4
#-------------SELENIUM----this for image concepts

# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq
from selenium import webdriver


firefox_options = webdriver.FirefoxOptions()
firefox_options.add_argument('--no-sandbox')
#firefox_options.add_argument('--headless')
firefox_options.add_argument('window-size=1920,1080');
firefox_options.add_argument('--disable-gpu')
driver = webdriver.Firefox(firefox_options=firefox_options)
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\ipykernel_launcher.py:12: DeprecationWarning: use options instead of firefox_options
#   if sys.path[0] == '':

# %%
test_url="https://www.monsterindia.com/srp/results?query=data%20scientist&searchId=754af010-3ca4-4df6-bbc6-eb3c88da1f77"

# %%
uClient = uReq(test_url) # requesting the webpage from the internet
mosnter_Page = uClient.read() # reading the webpage
uClient.close()

# %%
monster_html = bs(mosnter_Page, "html.parser") # parsing the webpage as HTML

# %%
monster_html
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <script async="true" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <meta content="noindex,follow" name="robots"/><title>200 Results Found for 'Data Scientist' Query | Monster India</title><meta content="Apply to 200 Data Scientist job openings on Monster India. Get best employment opportunity related to Data Scientist query." name="description"><script>var _seoHtmlProps_ = {"query":"data scientist","searchId":"754af010-3ca4-4df6-bbc6-eb3c88da1f77","start":0,"limit":25}</script><script>var _displayHtmlProps_ = {"query":"data scientist"}</script><script>var _seoPageLinkProps_ = {"prev":"", "next":""}</script>
# <script type="text/javascript">
# window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var o=e[n]={exports:{}};t[n][0].call(o.exports,function(e){var o=t[n][1][e];return r(o||e)},o,o.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<n.length;o++)r(n[o]);return r}({1:[function(t,e,n){function r(t){try{s.console&&console.log(t)}catch(e){}}var o,i=t("ee"),a=t(23),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,e,n){r(n.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,s){try{l?l-=1:o(s||new UncaughtException(t,e,n),!0)}catch(f){try{i("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function o(t,e){var n=e?null:c.now();i("err",[t,n])}var i=t("handle"),a=t(24),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,p="nr@seenError",l=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(13),t(12),"addEventListener"in window&&t(6),c.xhrWrappable&&t(14),d=!0)}s.on("fn-start",function(t,e,n){d&&(l+=1)}),s.on("fn-err",function(t,e,n){d&&!n[p]&&(f(n,p,function(){return!0}),this.thrown=!0,o(n))}),s.on("fn-end",function(){d&&!this.thrown&&l>0&&(l-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})},{}],3:[function(t,e,n){t("loader").features.ins=!0},{}],4:[function(t,e,n){function r(){j++,L=y.hash,this[u]=x.now()}function o(){j--,y.hash!==L&&i(0,!0);var t=x.now();this[h]=~~this[h]+t-this[u],this[d]=t}function i(t,e){E.emit("newURL",[""+y,e])}function a(t,e){t.on(e,function(){this[e]=x.now()})}var s="-start",c="-end",f="-body",u="fn"+s,d="fn"+c,p="cb"+s,l="cb"+c,h="jsTime",m="fetch",v="addEventListener",w=window,y=w.location,x=t("loader");if(w[v]&&x.xhrWrappable){var g=t(10),b=t(11),E=t(8),R=t(6),O=t(13),C=t(7),P=t(14),T=t(9),N=t("ee"),S=N.get("tracer");t(16),x.features.spa=!0;var L,j=0;N.on(u,r),N.on(p,r),N.on(d,o),N.on(l,o),N.buffer([u,d,"xhr-done","xhr-resolved"]),R.buffer([u]),O.buffer(["setTimeout"+c,"clearTimeout"+s,u]),P.buffer([u,"new-xhr","send-xhr"+s]),C.buffer([m+s,m+"-done",m+f+s,m+f+c]),E.buffer(["newURL"]),g.buffer([u]),b.buffer(["propagate",p,l,"executor-err","resolve"+s]),S.buffer([u,"no-"+u]),T.buffer(["new-jsonp","cb-start","jsonp-error","jsonp-end"]),a(P,"send-xhr"+s),a(N,"xhr-resolved"),a(N,"xhr-done"),a(C,m+s),a(C,m+"-done"),a(T,"new-jsonp"),a(T,"jsonp-end"),a(T,"cb-start"),E.on("pushState-end",i),E.on("replaceState-end",i),w[v]("hashchange",i,!0),w[v]("load",i,!0),w[v]("popstate",function(){i(0,j>1)},!0)}},{}],5:[function(t,e,n){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(13),s=t(12),c="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",p="resource",l="-start",h="-end",m="fn"+l,v="fn"+h,w="bstTimer",y="pushState",x=t("loader");x.features.stn=!0,t(8);var g=NREUM.o.EV;o.on(m,function(t,e){var n=t[0];n instanceof g&&(this.bstStart=x.now())}),o.on(v,function(t,e){var n=t[0];n instanceof g&&i("bst",[n,e,this.bstStart,x.now()])}),a.on(m,function(t,e,n){this.bstStart=x.now(),this.bstType=n}),a.on(v,function(t,e){i(w,[e,this.bstStart,x.now(),this.bstType])}),s.on(m,function(){this.bstStart=x.now()}),s.on(v,function(t,e){i(w,[e,this.bstStart,x.now(),"requestAnimationFrame"])}),o.on(y+l,function(t){this.time=x.now(),this.startPath=location.pathname+location.hash}),o.on(y+h,function(t){i("bstHist",[location.pathname+location.hash,this.startPath,this.time])}),f in window.performance&&(window.performance["c"+c]?window.performance ...
# ;NREUM.info={beacon:"bam.eu01.nr-data.net",errorBeacon:"bam.eu01.nr-data.net",licenseKey:"6923d0dfd2",applicationID:"6697735",sa:1}</script>
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#                                     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#                                     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#                                     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#                                     })(window,document,'script','dataLayer','GTM-NGL6ZM');
#                                 </script>
# <script type="text/javascript">
#                 var zmt_mtag;
#                 function zd_get_placements(){
#                     zmt_mtag = zmt_get_tag(3803,"313558");p313558_1 = zmt_mtag.zmt_get_placement("zt_313558_1", "313558", "1" , "173" , "14" , "1" ,"728", "90");p313558_2 = zmt_mtag.zmt_get_placement("zt_313558_2", "313558", "2" , "174" , "14" , "1" ,"728", "90");p313558_3 = zmt_mtag.zmt_get_placement("zt_313558_3", "313558", "3" , "175" , "14" , "1" ,"728", "90");p313558_4 = zmt_mtag.zmt_get_placement("zt_313558_4", "313558", "4" , "176" , "9" , "1" ,"300", "250");p313558_5 = zmt_mtag.zmt_get_placement("zt_313558_5", "313558", "5" , "177" , "7" , "1" ,"160", "600");;
#                     zmt_mtag.zmt_set_async();
#                     zmt_mtag.zmt_load(zmt_mtag);
#
#             }
#             </script>
# <style>.async-hide { opacity: 0 !important} </style>
# <script>(function(a,s,y,n,c,h,i,d,e){
#                     s.className+=' '+y;h.start=1*new Date;
#                     h.end=i=function(){s.className=s.className.replace(RegExp(' ?'+y),'')};
#                     (a[n]=a[n]||[]).hide=h;setTimeout(function(){i();h.end=null},c);h.timeout=c;
#                 })(window,document.documentElement,'async-hide','dataLayer',4000,{'GTM-K3TKGC8':true})</script>
# <link href="//media.monsterindia.com/trex/search/public/css/srp.css?version=202005141589445415" rel="stylesheet"/>
# </meta></head>
# <body class="wrapper-in">
# <!-- Setting Site Context -->
# <script>
#                 var version =  "20200514123029";
#                 var _siteProps_ = {
#                     name : "Monster India",
#                     tenant : "web",
#                     tenant_id : "1",
#                     category_id : "1",
#                     category_name : "Home",
#                     language : "",
#                     domain: "monsterindia.com",
#                     props: {"matomoSiteId":"1","showUserEngagement":"true","recruiterDetailsShow":"true","showPromotionsBox":"false","smart_apply":"false","oldLoginCheck":"true","showUploadViaGoogleDrive":"false","kiwi_subchannel_id":"1","gaAccountId":"UA-33916678-1","parseResumePhoenix":"true","parseNewResume":"true","parseResumeSwitchDesktop":"false","hideExperienceTypePopup":"true","kiwi_country_code":"IN","copyrightYear":"2020","showDesktopDropboxV2":"false","socialLoginOn":"true","kiwi_channel_id":"1","checkEmailExistence":"true"},
#                     isd: "91",
#                     country_id: "110",
#                     country_code: "IN",
#                     currency_id: "4",
#                     currency_name: "Indian Rupees",
#                     currency_code: "INR",
#                     currency_sign: "?",
#                     under_maintainance: "0",
#             		siteContext: "rexmonster",
#             		favicon: ""
#
#                 };
#                 var _ssoPath_ = {
#                     riologinPath: "http://www.monsterindia.com/rio/login/seeker",
#                     rioLogoutPath: "http://www.monsterindia.com/rio/logout"
#                 };
#             </script>
# <link href="//media.monsterindia.com/trex/public/default/dist/css/app.css?ver=010520202228" rel="stylesheet" type="text/css">
# <div class="pg-wrapper" id="headerDefault">
# <header-top-links data-service="[{&quot;module_tag&quot;:null,&quot;menu_group&quot;:&quot;TopLinks&quot;,&quot;module_alias&quot;:null,&quot;menu_type&quot;:&quot;link&quot;,&quot;parent_id&quot;:null,&quot;site_id&quot;:1,&quot;name&quot;:&quot;Job search&quot;,&quot;id&quot;:130,&quot;link_rewrite&quot;:&quot;/job-search.html&quot;},{&quot;module_tag&quot;:null,&quot;menu_group&quot;:&quot;TopLinks&quot;,&quot;module_alias&quot;:null,&quot;menu_type&quot;:&quot;link&quot;,&quot;parent_id&quot;:130,&quot;site_id&quot;:1,&quot;name&quot;:&quot;Jobs By Company&quot;,&quot;id&quot;:135,&quot;link_rewrite&quot;:&quot;https://my.monsterindia.com/find-companies.html&quot;},{&quot;module_tag&quot;:null,&quot;menu_group&quot;:&quot;TopLinks&quot;,&quot;module_alias&quot;:null,&quot;menu_type&quot;:&quot;link&quot;,&quot;parent_id&quot;:130,&quot;site_id&quot;:1,&quot;name&quot;:&quot;Jobs By Function&quot;,&quot;id&quot;:136,&quot;link_rewrite&quot;:&quot;/jobs-by-function.html&quot;},{&quot;module_tag&quot;:null,&quot;menu_group&quot;:&quot;TopLinks&quot;,&quot;module_alias&quot;:null,&quot;menu_type&quot;:&quot;link&quot;,&quot;parent_id&quot;:130,&quot;site_id&quot;:1,&quot;name&quot;:&quot;Jobs By Industry&quot;,&quot;id&quot;:137,&quot;link_rewrite&quot;:&quot;/jobs-by-industry.html&quot;},{&quot;module_tag&quot;:null,&quot;menu_group&quot;:&quot;TopLinks&quot;,&quot;module_alias&quot;:null,&quot;menu_type&quot;:&quot;link&quot;,&quot;parent_id&quot;:130,&quot;site_id&quot;:1,&quot;name&quot;:&quot;Jobs by Location&quot;,&quot;id&quot;:138,&quot;link_rewrite&quot;:&quot;/jobs-by-location.html&quot;},{&quot;module_tag&quot;:null,&quot;menu_group&quot;:&quot;TopLinks&quot;,&quot;module_alias&quot;:null,&quot;menu_type&quot;:&quot;link&quot;,&quot;parent_id&quot;:130,&quot;site_id&quot;:1,&quot;name&quot;:&quot;Jobs by Recruiter&quot;,&quot;id&quot;:139,&quot;link_rewrite&quot;:&quot;https://my.monsterindia.com/find-recruiters.html&quot;},{&quot;module_tag&quot;:null,&quot;menu_group&quot;:&quot;TopLinks&quot;,&quot;module_alias&quot;:null,&quot;menu_type&quot;:&quot;link&quot;,&quot;parent_id&quot;:130,&quot;site_id&quot;:1,&quot;name&quot;:&quot;Fresher Jobs&quot;,&quot;id&quot;:293,&quot;link_rewrite&quot;:&quot;/search/freshers-jobs&quot;},{&quot;module_tag&quot;:null,&quot;menu_group&quot;:&quot;TopLinks&quot;,&quot;module_alias&quot;:null,&quot;menu_type&quot;:&quot;link&quot;,&quot;parent_id&quot;:130,&quot;site_id&quot;:1,&quot;name&quot;:&quot;Jobs by Skills&quot;,&quot;id&quot;:140,&quot;link_rewrite&quot;:&quot;/jobs-by-skill.html&quot;},{&quot;module_tag&quot;:null,&quot;menu_group&quot;:&quot;TopLinks&quot;,&quot;module_alias&quot;:null,&quot;menu_type&quot;:&quot;link&quot;,&quot;parent_id&quot;:130,&quot;site_id&quot;:1,&quot;name&quot;:&quot;Jobs For Women&quot;,&quot;id&quot;:141,&quot;link_rewrite&quot;:&quot;/search/jobs-for-women-jobs&quot;},{&quot;module_tag&quot;:null,&quot;menu_group&quot;:&quot;TopLinks&quot;,&quot;module_alias&quot;:null,&quot;menu_type&quot;:&quot;link&quot;,&quot;parent_id&quot;:130,&quot;site_id&quot;:1,&quot;name&quot;:&quot;Special Ability Jobs&quot;,&quot;id&quot;:291,&quot;link_rewrite&quot;:&quot;http://www.ciispecialabilityjobs.in/&quot;},{&quot;module_tag&quot;:null,&quot;menu_group&quot;:&quot;TopLinks&quot;,&quot;module_alias&quot;:null,&quot;menu_type&quot;:&quot;link&quot;,&quot;parent_id&quot;:130,&quot;site_id&quot;:1,&quot;name&quot;:&quot;Work from Home jobs&quot;,&quot;id&quot;:1381,&quot;link_rewrite&quot;:&quot;/srp/results?sort=2&amp;limit=25&amp;jobTypes=work%20from%20home&amp;filter=true&quot;},{&quot;module_tag&quot;:null,&quot;menu_group&quot;:&quot;TopLinks&quot;,&quot;module_alias&quot;:null,&quot;menu_type&quot;:&quot;link&quot;,&quot;parent_id&quot;:null,&quot;site_id&quot;:1,&quot;name&quot;:&quot;Work from Home&quot;,&quot;id&quot;:1390,&quot;link_rewrite&quot;:&quot;/srp/results?sort=2&amp;limit=25&amp;jobTypes=work%20from%20home&amp;filter=true&quot;},{&qu ...
# <script>
#     /*<![CDATA[*/
#
#         // var headerTopLinks = /*"[{\"module_tag\":null,\"menu_group\":\"TopLinks\",\"module_alias\":null,\"menu_type\":\"link\",\"parent_id\":null,\"site_id\":1,\"name\":\"Job search\",\"id\":130,\"link_rewrite\":\"\/job-search.html\"},{\"module_tag\":null,\"menu_group\":\"TopLinks\",\"module_alias\":null,\"menu_type\":\"link\",\"parent_id\":130,\"site_id\":1,\"name\":\"Jobs By Company\",\"id\":135,\"link_rewrite\":\"https:\/\/my.monsterindia.com\/find-companies.html\"},{\"module_tag\":null,\"menu_group\":\"TopLinks\",\"module_alias\":null,\"menu_type\":\"link\",\"parent_id\":130,\"site_id\":1,\"name\":\"Jobs By Function\",\"id\":136,\"link_rewrite\":\"\/jobs-by-function.html\"},{\"module_tag\":null,\"menu_group\":\"TopLinks\",\"module_alias\":null,\"menu_type\":\"link\",\"parent_id\":130,\"site_id\":1,\"name\":\"Jobs By Industry\",\"id\":137,\"link_rewrite\":\"\/jobs-by-industry.html\"},{\"module_tag\":null,\"menu_group\":\"TopLinks\",\"module_alias\":null,\"menu_type\":\"link\",\"parent_id\":130,\"site_id\":1,\"name\":\"Jobs by Location\",\"id\":138,\"link_rewrite\":\"\/jobs-by-location.html\"},{\"module_tag\":null,\"menu_group\":\"TopLinks\",\"module_alias\":null,\"menu_type\":\"link\",\"parent_id\":130,\"site_id\":1,\"name\":\"Jobs by Recruiter\",\"id\":139,\"link_rewrite\":\"https:\/\/my.monsterindia.com\/find-recruiters.html\"},{\"module_tag\":null,\"menu_group\":\"TopLinks\",\"module_alias\":null,\"menu_type\":\"link\",\"parent_id\":130,\"site_id\":1,\"name\":\"Fresher Jobs\",\"id\":293,\"link_rewrite\":\"\/search\/freshers-jobs\"},{\"module_tag\":null,\"menu_group\":\"TopLinks\",\"module_alias\":null,\"menu_type\":\"link\",\"parent_id\":130,\"site_id\":1,\"name\":\"Jobs by Skills\",\"id\":140,\"link_rewrite\":\"\/jobs-by-skill.html\"},{\"module_tag\":null,\"menu_group\":\"TopLinks\",\"module_alias\":null,\"menu_type\":\"link\",\"parent_id\":130,\"site_id\":1,\"name\":\"Jobs For Women\",\"id\":141,\"link_rewrite\":\"\/search\/jobs-for-women-jobs\"},{\"module_tag\":null,\"menu_group\":\"TopLinks\",\"module_alias\":null,\"menu_type\":\"link\",\"parent_id\":130,\"site_id\":1,\"name\":\"Special Ability Jobs\",\"id\":291,\"link_rewrite\":\"http:\/\/www.ciispecialabilityjobs.in\/\"},{\"module_tag\":null,\"menu_group\":\"TopLinks\",\"module_alias\":null,\"menu_type\":\"link\",\"parent_id\":130,\"site_id\":1,\"name\":\"Work from Home jobs\",\"id\":1381,\"link_rewrite\":\"\/srp\/results?sort=2\u0026limit=25\u0026jobTypes=work%20from%20home\u0026filter=true\"},{\"module_tag\":null,\"menu_group\":\"TopLinks\",\"module_alias\":null,\"menu_type\":\"link\",\"parent_id\":null,\"site_id\":1,\"name\":\"Work from Home\",\"id\":1390,\"link_rewrite\":\"\/srp\/results?sort=2\u0026limit=25\u0026jobTypes=work%20from%20home\u0026filter=true\"},{\"module_tag\":null,\"menu_group\":\"TopLinks\",\"module_alias\":null,\"menu_type\":\"link\",\"parent_id\":1390,\"site_id\":1,\"name\":\"Work from Home Jobs in Bangalore\",\"id\":1391,\"link_rewrite\":\"\/srp\/results?sort=2\u0026limit=25\u0026jobTypes=work from home\u0026jobCities=bengaluru %2f bangalore\u0026filter=true\"},{\"module_tag\":null,\"menu_group\":\"TopLinks\",\"module_alias\":null,\"menu_type\":\"link\",\"parent_id\":1390,\"site_id\":1,\"name\":\"Work from Home Jobs in Mumbai\",\"id\":1392,\"link_rewrite\":\"\/srp\/results?sort=2\u0026limit=25\u0026jobTypes=work%20from%20home\u0026jobCities=mumbai\u0026filter=true\"},{\"module_tag\":null,\"menu_group\":\"TopLinks\",\"module_alias\":null,\"menu_type\":\"link\",\"parent_id\":1390,\"site_id\":1,\"name\":\"Work from Home Jobs in Chennai\",\"id\":1393,\"link_rewrite\":\"\/srp\/results?sort=2\u0026limit=25\u0026jobTypes=work%20from%20home\u0026jobCities=chennai\u0026filter=true\"},{\"module_tag\":null,\"menu_group\":\"TopLinks\",\"module_alias\":null,\"menu_type\":\"link\",\"parent_id\":1390,\"site_id\":1,\"name\":\"Work from Home Jobs in Hyderabad\",\"id\":1394,\"link_rewrite\":\"\/srp\/results?sort=2\u0026limit=25\u0026jobTypes=work%20from%2 ...
#         // console.log('headerTopLinks....****', headerTopLinks);
#
#     /*]]>*/
#
#
#
#
#
#
# </script><header-main data-service="[{&quot;module_tag&quot;:null,&quot;menu_group&quot;:&quot;TopLinks&quot;,&quot;module_alias&quot;:null,&quot;menu_type&quot;:&quot;link&quot;,&quot;parent_id&quot;:null,&quot;site_id&quot;:1,&quot;name&quot;:&quot;Job search&quot;,&quot;id&quot;:130,&quot;link_rewrite&quot;:&quot;/job-search.html&quot;},{&quot;module_tag&quot;:null,&quot;menu_group&quot;:&quot;TopLinks&quot;,&quot;module_alias&quot;:null,&quot;menu_type&quot;:&quot;link&quot;,&quot;parent_id&quot;:130,&quot;site_id&quot;:1,&quot;name&quot;:&quot;Jobs By Company&quot;,&quot;id&quot;:135,&quot;link_rewrite&quot;:&quot;https://my.monsterindia.com/find-companies.html&quot;},{&quot;module_tag&quot;:null,&quot;menu_group&quot;:&quot;TopLinks&quot;,&quot;module_alias&quot;:null,&quot;menu_type&quot;:&quot;link&quot;,&quot;parent_id&quot;:130,&quot;site_id&quot;:1,&quot;name&quot;:&quot;Jobs By Function&quot;,&quot;id&quot;:136,&quot;link_rewrite&quot;:&quot;/jobs-by-function.html&quot;},{&quot;module_tag&quot;:null,&quot;menu_group&quot;:&quot;TopLinks&quot;,&quot;module_alias&quot;:null,&quot;menu_type&quot;:&quot;link&quot;,&quot;parent_id&quot;:130,&quot;site_id&quot;:1,&quot;name&quot;:&quot;Jobs By Industry&quot;,&quot;id&quot;:137,&quot;link_rewrite&quot;:&quot;/jobs-by-industry.html&quot;},{&quot;module_tag&quot;:null,&quot;menu_group&quot;:&quot;TopLinks&quot;,&quot;module_alias&quot;:null,&quot;menu_type&quot;:&quot;link&quot;,&quot;parent_id&quot;:130,&quot;site_id&quot;:1,&quot;name&quot;:&quot;Jobs by Location&quot;,&quot;id&quot;:138,&quot;link_rewrite&quot;:&quot;/jobs-by-location.html&quot;},{&quot;module_tag&quot;:null,&quot;menu_group&quot;:&quot;TopLinks&quot;,&quot;module_alias&quot;:null,&quot;menu_type&quot;:&quot;link&quot;,&quot;parent_id&quot;:130,&quot;site_id&quot;:1,&quot;name&quot;:&quot;Jobs by Recruiter&quot;,&quot;id&quot;:139,&quot;link_rewrite&quot;:&quot;https://my.monsterindia.com/find-recruiters.html&quot;},{&quot;module_tag&quot;:null,&quot;menu_group&quot;:&quot;TopLinks&quot;,&quot;module_alias&quot;:null,&quot;menu_type&quot;:&quot;link&quot;,&quot;parent_id&quot;:130,&quot;site_id&quot;:1,&quot;name&quot;:&quot;Govt. Jobs&quot;,&quot;id&quot;:294,&quot;link_rewrite&quot;:&quot;/government-jobs/&quot;},{&quot;module_tag&quot;:null,&quot;menu_group&quot;:&quot;TopLinks&quot;,&quot;module_alias&quot;:null,&quot;menu_type&quot;:&quot;link&quot;,&quot;parent_id&quot;:130,&quot;site_id&quot;:1,&quot;name&quot;:&quot;Fresher Jobs&quot;,&quot;id&quot;:293,&quot;link_rewrite&quot;:&quot;/search/freshers-jobs&quot;},{&quot;module_tag&quot;:null,&quot;menu_group&quot;:&quot;TopLinks&quot;,&quot;module_alias&quot;:null,&quot;menu_type&quot;:&quot;link&quot;,&quot;parent_id&quot;:130,&quot;site_id&quot;:1,&quot;name&quot;:&quot;Jobs by Skills&quot;,&quot;id&quot;:140,&quot;link_rewrite&quot;:&quot;/jobs-by-skill.html&quot;},{&quot;module_tag&quot;:null,&quot;menu_group&quot;:&quot;TopLinks&quot;,&quot;module_alias&quot;:null,&quot;menu_type&quot;:&quot;link&quot;,&quot;parent_id&quot;:130,&quot;site_id&quot;:1,&quot;name&quot;:&quot;Jobs For Women&quot;,&quot;id&quot;:141,&quot;link_rewrite&quot;:&quot;/search/jobs-for-women-jobs&quot;},{&quot;module_tag&quot;:null,&quot;menu_group&quot;:&quot;TopLinks&quot;,&quot;module_alias&quot;:null,&quot;menu_type&quot;:&quot;link&quot;,&quot;parent_id&quot;:130,&quot;site_id&quot;:1,&quot;name&quot;:&quot;Other Jobs&quot;,&quot;id&quot;:142,&quot;link_rewrite&quot;:&quot;/other-jobs.html&quot;},{&quot;module_tag&quot;:null,&quot;menu_group&quot;:&quot;TopLinks&quot;,&quot;module_alias&quot;:null,&quot;menu_type&quot;:&quot;link&quot;,&quot;parent_id&quot;:130,&quot;site_id&quot;:1,&quot;name&quot;:&quot;Special Ability Jobs&quot;,&quot;id&quot;:291,&quot;link_rewrite&quot;:&quot;http://www.ciispecialabilityjobs.in/&quot;},{&quot;module_tag&quot;:null,&quot;menu_group&quot;:&quot;TopLinks&quot;,&quot;module_alias&quot;:null,&quot;menu_type&quot;:&quot;link&quot;,& ...
# </div>
# <script charset="UTF-8" src="//media.monsterindia.com/trex/public/default/dist/js/header.js?v=1567676754534"></script>
# <script>
#             var _rs_monster = _rs_monster || [];
#             /* getting useragent */
#             function getUseragent() {
#                 var userAgent = navigator.userAgent || navigator.vendor || window.opera;
#                 if (/windows phone/i.test(userAgent)) {
#                     return "windows phone";
#                 }
#                 if (/android/i.test(userAgent)) {
#                     return "android";
#                 }
#                 if (/iPad|iPhone|iPod/.test(userAgent) && !window.MSStream) {
#                     return "ios";
#                 }
#                 return "unknown";
#             }
#             var checkUseragent = getUseragent();
#             /* eof getting useragent */
#             if (typeof _siteProps_ != 'undefined') {
#                 var obj = {
#                     accessedUrl: window.location.pathname,
#                     action: 'onLoad',
#                     channel: (typeof _siteProps_ != 'undefined' && typeof _siteProps_.props != 'undefined' && typeof _siteProps_.props.kiwi_channel_id != 'undefined') ? _siteProps_.props.kiwi_channel_id :  '',
#                     id: _siteProps_.category_id ? _siteProps_.category_id : '',
#                     site: _siteProps_.name ? _siteProps_.name : '',
#                     tenant: checkUseragent != 'unknown' ? checkUseragent : 'web',
#                     userAgent: navigator.userAgent
#                 };
#                 _rs_monster.push(obj);
#             }
#         </script>
# <script> var zedoContextWiseId = 313558;</script>
# <div class="pg-wrapper push-content-down" id="srpThemeDefault"><search-results></search-results></div>
# <script src="//media.monsterindia.com/trex/search/public/js/srp.js?version=202005141589445415"></script>
# <script charset="utf-8" type="text/javascript"> (function(g,o){g[o]=g[o]||function(){(g[o]['q']=g[o]['q']||[]).push(arguments)},g[o]['t']=1*new Date})(window,'_googCsa'); </script>
# <!-- Setting Site Context -->
# <footer class="monq-footer">
# <style>
#                 #reportBug {
#                     display: none;
#                 }
#             </style>
# <div class="pg-wrapper" id="footerDefault">
# <seo-footer data-seo-footer-links='[{"module_tag":null,"menu_group":"seoFooterLinks","module_alias":null,"menu_type":"link","parent_id":null,"site_id":1,"name":"Jobs by Locations","id":54,"link_rewrite":"/jobs-by-location.html"},{"module_tag":null,"menu_group":"seoFooterLinks","module_alias":null,"menu_type":"link","parent_id":54,"site_id":1,"name":"Jobs in Bangalore","id":55,"link_rewrite":"/search/jobs-in-bangalore"},{"module_tag":null,"menu_group":"seoFooterLinks","module_alias":null,"menu_type":"link","parent_id":54,"site_id":1,"name":"Jobs in Delhi","id":58,"link_rewrite":"/search/jobs-in-delhi"},{"module_tag":null,"menu_group":"seoFooterLinks","module_alias":null,"menu_type":"link","parent_id":54,"site_id":1,"name":"Jobs in Mumbai","id":67,"link_rewrite":"/search/jobs-in-mumbai"},{"module_tag":null,"menu_group":"seoFooterLinks","module_alias":null,"menu_type":"link","parent_id":54,"site_id":1,"name":"Jobs in Chennai","id":68,"link_rewrite":"/search/jobs-in-chennai"},{"module_tag":null,"menu_group":"seoFooterLinks","module_alias":null,"menu_type":"link","parent_id":54,"site_id":1,"name":"Jobs in Hyderabad","id":69,"link_rewrite":"/search/jobs-in-hyderabad"},{"module_tag":null,"menu_group":"seoFooterLinks","module_alias":null,"menu_type":"link","parent_id":54,"site_id":1,"name":"Jobs in Kolkata","id":70,"link_rewrite":"/search/jobs-in-kolkata"},{"module_tag":null,"menu_group":"seoFooterLinks","module_alias":null,"menu_type":"link","parent_id":54,"site_id":1,"name":"Jobs in Pune","id":71,"link_rewrite":"/search/jobs-in-pune"},{"module_tag":null,"menu_group":"seoFooterLinks","module_alias":null,"menu_type":"link","parent_id":54,"site_id":1,"name":"Jobs in Chandigarh","id":72,"link_rewrite":"/search/jobs-in-chandigarh"},{"module_tag":null,"menu_group":"seoFooterLinks","module_alias":null,"menu_type":"link","parent_id":54,"site_id":1,"name":"Jobs in Lucknow","id":73,"link_rewrite":"/search/jobs-in-lucknow"},{"module_tag":null,"menu_group":"seoFooterLinks","module_alias":null,"menu_type":"link","parent_id":54,"site_id":1,"name":"Jobs in Coimbatore","id":74,"link_rewrite":"/search/jobs-in-coimbatore"},{"module_tag":null,"menu_group":"seoFooterLinks","module_alias":null,"menu_type":"link","parent_id":null,"site_id":1,"name":"Jobs by Skill - IT","id":75,"link_rewrite":"/search/it-jobs"},{"module_tag":null,"menu_group":"seoFooterLinks","module_alias":null,"menu_type":"link","parent_id":75,"site_id":1,"name":"Biotechnology Jobs","id":76,"link_rewrite":"/search/biotechnology-jobs"},{"module_tag":null,"menu_group":"seoFooterLinks","module_alias":null,"menu_type":"link","parent_id":75,"site_id":1,"name":"Digital Marketing Jobs","id":77,"link_rewrite":"/search/digital-marketing-jobs"},{"module_tag":null,"menu_group":"seoFooterLinks","module_alias":null,"menu_type":"link","parent_id":75,"site_id":1,"name":"Graphic Design Jobs","id":78,"link_rewrite":"/search/graphic-design-jobs"},{"module_tag":null,"menu_group":"seoFooterLinks","module_alias":null,"menu_type":"link","parent_id":75,"site_id":1,"name":"Networking Jobs","id":79,"link_rewrite":"/search/networking-jobs"},{"module_tag":null,"menu_group":"seoFooterLinks","module_alias":null,"menu_type":"link","parent_id":75,"site_id":1,"name":"Oracle Jobs","id":80,"link_rewrite":"/search/oracle-jobs"},{"module_tag":null,"menu_group":"seoFooterLinks","module_alias":null,"menu_type":"link","parent_id":80,"site_id":1,"name":"PHP Jobs","id":81,"link_rewrite":"/search/php-jobs"},{"module_tag":null,"menu_group":"seoFooterLinks","module_alias":null,"menu_type":"link","parent_id":75,"site_id":1,"name":"SEO Jobs","id":82,"link_rewrite":"/search/seo-jobs"},{"module_tag":null,"menu_group":"seoFooterLinks","module_alias":null,"menu_type":"link","parent_id":75,"site_id":1,"name":"Software Testing Jobs","id":83,"link_rewrite":"/search/software-testing-jobs"},{"module_tag":null,"menu_group":"seoFooterLinks","module_alias":null,"menu_type":"link","parent_id":75,"site_id":1,"name":"Sql Jobs","id":84,"link_rewri ...
# <static-module></static-module>
# </div>
# </footer>
# <script charset="UTF-8" src="//media.monsterindia.com/trex/public/default/dist/js/footer.js?v=20200514123029"></script>
# <script src="//media.monsterindia.com/trex/search/public/js/utility/gaTrack.js?version=202005141589445415"></script>
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-NGL6ZM" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# </link></body>
# </html>

# %%
monster_url = "https://www.monsterindia.com/srp/results?query=Data Scientist"
driver.get(monster_url)
driver.implicitly_wait(30)
source = driver.page_source

# %%
html = bs(source, "html.parser")  # parsing the webpage as HTML

#print(html)

bigboxes = html.findAll("div", {
                    "class": "card-apply-content"})

# %%
job_link="https:"+bigboxes[0].find("div", {
                    "class": "job-tittle"}).h3.a['href']
job_link
# Out:
# 'https://www.monsterindia.com/seeker/job-details?id=1465066'

# %%
job_title=bigboxes[0].find("div", {
                    "class": "job-tittle"}).h3.a.text

job_title
# Out:
# 'Senior Data Scientist'

# %%
company_name=bigboxes[0].find("div", {
                    "class": "job-tittle"}).span.a.text
company_name
# Out:
# 'Hyper Think Systems Private Limited'

# %%
job_location=bigboxes[0].find("div", {
                    "class": "job-tittle"}).div.span.small.text.strip()
job_location
# Out:
# 'Oman'

# %%
skill_box=bigboxes[0].find("p",{"class":"descrip-skills"}).findAll("span",{"class":"grey-link"})

# %%
for skill in skill_box:
    print(skill.a.text.strip())
# Out:
# Data Scientist AND Python AND R AND Predictive modelling
#                         ,
# DL
#                         ,
# AI AND Data Analytics
#                         ,
# Machine Learning AND BFSI
#                         ,
# Ml

# %%
job_posting_time=html.findAll("div",{"class":"card-panel apply-panel job-apply-card"})[0].findAll("div",{"class":"card-footer apply-footer no-bdr"})[0].span.text.strip()
job_posting_time
# Out:
# 'Posted: a month ago'
